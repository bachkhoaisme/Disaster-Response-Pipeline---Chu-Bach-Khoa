# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
from sqlalchemy import create_engine
import nltk
nltk.download(['punkt', 'wordnet'])

import re
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('DisasterResponse',engine)
X = df.message
y = df[df.columns[4:]]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
category_names = y.columns
y_pred = pipeline.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i], target_names=category_names), '...................................................')
# Out:
# ('related',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.60      0.35      0.44      1516
#                ('request',)       0.82      0.93      0.87      4982
#                  ('offer',)       0.45      0.16      0.24        56
#
#                 avg / total       0.76      0.79      0.77      6554
#  ...................................................
# ('request',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.89      0.98      0.93      5428
#                ('request',)       0.81      0.40      0.54      1126
#
#                 avg / total       0.87      0.88      0.86      6554
#  ...................................................
# ('offer',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       1.00      1.00      1.00      6533
#                ('request',)       0.00      0.00      0.00        21
#
#                 avg / total       0.99      1.00      1.00      6554
#  ...................................................
# ('aid_related',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.73      0.88      0.80      3855
#                ('request',)       0.76      0.53      0.62      2699
#
#                 avg / total       0.74      0.74      0.73      6554
#  ...................................................
# ('medical_help',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.92      0.99      0.96      6023
#                ('request',)       0.53      0.08      0.14       531
#
#                 avg / total       0.89      0.92      0.89      6554
#  ...................................................
# ('medical_products',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.95      1.00      0.97      6212
#                ('request',)       0.78      0.07      0.13       342
#
#                 avg / total       0.94      0.95      0.93      6554
#  ...................................................
# ('search_and_rescue',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.97      1.00      0.99      6368
#                ('request',)       0.53      0.04      0.08       186
#
#                 avg / total       0.96      0.97      0.96      6554
#  ...................................................
# ('security',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.98      1.00      0.99      6437
#                ('request',)       0.00      0.00      0.00       117
#
#                 avg / total       0.96      0.98      0.97      6554
#  ...................................................
# ('military',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.97      1.00      0.99      6365
#                ('request',)       0.50      0.06      0.11       189
#
#                 avg / total       0.96      0.97      0.96      6554
#  ...................................................
# ('child_alone',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       1.00      1.00      1.00      6554
#
#                 avg / total       1.00      1.00      1.00      6554
#  ...................................................
# ('water',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.95      1.00      0.98      6127
#                ('request',)       0.86      0.33      0.47       427
#
#                 avg / total       0.95      0.95      0.94      6554
#  ...................................................
# ('food',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.92      0.99      0.96      5794
#                ('request',)       0.84      0.37      0.51       760
#
#                 avg / total       0.91      0.92      0.90      6554
#  ...................................................
# ('shelter',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.94      0.99      0.96      5982
#                ('request',)       0.82      0.28      0.42       572
#
#                 avg / total       0.93      0.93      0.92      6554
#  ...................................................
# ('clothing',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      0.99      6447
#                ('request',)       0.79      0.14      0.24       107
#
#                 avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('money',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.98      1.00      0.99      6392
#                ('request',)       0.75      0.02      0.04       162
#
#                 avg / total       0.97      0.98      0.96      6554
#  ...................................................
# ('missing_people',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      0.99      6486
#                ('request',)       0.00      0.00      0.00        68
#
#                 avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('refugees',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.97      1.00      0.98      6338
#                ('request',)       0.55      0.05      0.09       216
#
#                 avg / total       0.95      0.97      0.95      6554
#  ...................................................
# ('death',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.96      1.00      0.98      6232
#                ('request',)       0.81      0.09      0.16       322
#
#                 avg / total       0.95      0.95      0.94      6554
#  ...................................................
# ('other_aid',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.87      1.00      0.93      5700
#                ('request',)       0.55      0.03      0.06       854
#
#                 avg / total       0.83      0.87      0.82      6554
#  ...................................................
# ('infrastructure_related',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.94      1.00      0.97      6143
#                ('request',)       0.33      0.01      0.01       411
#
#                 avg / total       0.90      0.94      0.91      6554
#  ...................................................
# ('transport',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.95      1.00      0.98      6232
#                ('request',)       0.76      0.08      0.14       322
#
#                 avg / total       0.94      0.95      0.94      6554
#  ...................................................
# ('buildings',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.96      1.00      0.98      6241
#                ('request',)       0.66      0.09      0.15       313
#
#                 avg / total       0.94      0.95      0.94      6554
#  ...................................................
# ('electricity',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.98      1.00      0.99      6406
#                ('request',)       0.83      0.03      0.06       148
#
#                 avg / total       0.97      0.98      0.97      6554
#  ...................................................
# ('tools',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      1.00      6506
#                ('request',)       0.00      0.00      0.00        48
#
#                 avg / total       0.99      0.99      0.99      6554
#  ...................................................
# ('hospitals',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      0.99      6475
#                ('request',)       0.00      0.00      0.00        79
#
#                 avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('shops',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       1.00      1.00      1.00      6525
#                ('request',)       0.00      0.00      0.00        29
#
#                 avg / total       0.99      1.00      0.99      6554
#  ...................................................
# ('aid_centers',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      0.99      6484
#                ('request',)       0.00      0.00      0.00        70
#
#                 avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('other_infrastructure',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.96      1.00      0.98      6278
#                ('request',)       0.40      0.01      0.01       276
#
#                 avg / total       0.93      0.96      0.94      6554
#  ...................................................
# ('weather_related',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.84      0.96      0.90      4717
#                ('request',)       0.84      0.52      0.65      1837
#
#                 avg / total       0.84      0.84      0.83      6554
#  ...................................................
# ('floods',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.94      1.00      0.97      6013
#                ('request',)       0.89      0.33      0.48       541
#
#                 avg / total       0.94      0.94      0.93      6554
#  ...................................................
# ('storm',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.92      0.99      0.96      5887
#                ('request',)       0.77      0.27      0.40       667
#
#                 avg / total       0.91      0.92      0.90      6554
#  ...................................................
# ('fire',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.99      1.00      0.99      6479
#                ('request',)       0.00      0.00      0.00        75
#
#                 avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('earthquake',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.97      0.99      0.98      5966
#                ('request',)       0.87      0.65      0.75       588
#
#                 avg / total       0.96      0.96      0.96      6554
#  ...................................................
# ('cold',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.98      1.00      0.99      6428
#                ('request',)       0.60      0.07      0.13       126
#
#                 avg / total       0.97      0.98      0.97      6554
#  ...................................................
# ('other_weather',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.95      1.00      0.98      6232
#                ('request',)       0.60      0.04      0.07       322
#
#                 avg / total       0.94      0.95      0.93      6554
#  ...................................................
# ('direct_report',) :
#                              precision    recall  f1-score   support
#
#                ('related',)       0.86      0.98      0.91      5245
#                ('request',)       0.80      0.34      0.47      1309
#
#                 avg / total       0.84      0.85      0.83      6554
#  ...................................................
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 2, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 1, does not match size of target_names, 36
#   .format(len(labels), len(target_names))

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x7f3a9064b620>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=1))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x7f3a9064b620>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=1),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 10,
#  'clf__estimator__n_jobs': 1,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'clf__n_jobs': 1}

# %%
parameters = {
    'clf__estimator__n_estimators': [5, 10, 15],
    'clf__estimator__min_samples_split': [2, 3, 4],
}

cv = GridSearchCV(pipeline, param_grid=parameters, n_jobs=4, verbose=2)

# %%
cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5, total= 2.0min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5, total= 2.0min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=5, total= 2.0min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, total= 3.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, total= 3.2min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, total= 3.2min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15, total= 4.4min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5, total= 1.8min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15, total= 4.4min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5, total= 1.8min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=5, total= 1.9min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=15, total= 4.5min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, total= 2.9min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, total= 2.9min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, total= 2.9min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15, total= 4.0min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5, total= 1.7min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15, total= 4.0min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=15, total= 4.0min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5, total= 1.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=5, total= 1.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10, total= 2.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10, total= 2.8min
# [CV] clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=10, total= 2.8min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15, total= 3.5min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15, total= 3.0min
# [CV]  clf__estimator__min_samples_split=4, clf__estimator__n_estimators=15, total= 2.4min
# [Parallel(n_jobs=4)]: Done  27 out of  27 | elapsed: 24.5min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'clf__estimator__n_estimators': [5, 10, 15], 'clf__estimator__min_samples_split': [2, 3, 4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
cv.grid_scores_
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.23421, std: 0.00698, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 50},
#  mean: 0.23787, std: 0.00572, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 100},
#  mean: 0.24021, std: 0.00717, params: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 150},
#  mean: 0.23141, std: 0.00589, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 50},
#  mean: 0.24031, std: 0.00527, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 100},
#  mean: 0.23909, std: 0.00652, params: {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 150},
#  mean: 0.23004, std: 0.00373, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 50},
#  mean: 0.23487, std: 0.00642, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 100},
#  mean: 0.23919, std: 0.00699, params: {'clf__estimator__min_samples_split': 4, 'clf__estimator__n_estimators': 150}]

# %%
print(cv.best_params_)
# Out:
# {'clf__estimator__min_samples_split': 3, 'clf__estimator__n_estimators': 100}

# %%
optimised_model = cv.best_estimator_
print (cv.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_pred = optimised_model.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i]), '...................................................')
# Out:
# ('related',) :
#              precision    recall  f1-score   support
#
#           0       0.72      0.27      0.39      1504
#           1       0.81      0.97      0.88      4998
#           2       0.53      0.15      0.24        52
#
# avg / total       0.79      0.80      0.76      6554
#  ...................................................
# ('request',) :
#              precision    recall  f1-score   support
#
#           0       0.90      0.99      0.94      5473
#           1       0.91      0.46      0.61      1081
#
# avg / total       0.90      0.90      0.89      6554
#  ...................................................
# ('offer',) :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6523
#           1       0.00      0.00      0.00        31
#
# avg / total       0.99      1.00      0.99      6554
#  ...................................................
# ('aid_related',) :
#              precision    recall  f1-score   support
#
#           0       0.77      0.89      0.83      3843
#           1       0.80      0.63      0.70      2711
#
# avg / total       0.78      0.78      0.77      6554
#  ...................................................
# ('medical_help',) :
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6043
#           1       0.63      0.06      0.12       511
#
# avg / total       0.90      0.92      0.89      6554
#  ...................................................
# ('medical_products',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6226
#           1       0.79      0.07      0.12       328
#
# avg / total       0.94      0.95      0.93      6554
#  ...................................................
# ('search_and_rescue',) :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6349
#           1       0.71      0.02      0.05       205
#
# avg / total       0.96      0.97      0.96      6554
#  ...................................................
# ('security',) :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.50      0.01      0.02       123
#
# avg / total       0.97      0.98      0.97      6554
#  ...................................................
# ('military',) :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6336
#           1       0.50      0.05      0.08       218
#
# avg / total       0.95      0.97      0.95      6554
#  ...................................................
# ('child_alone',) :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#  ...................................................
# ('water',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6155
#           1       0.97      0.22      0.36       399
#
# avg / total       0.95      0.95      0.94      6554
#  ...................................................
# ('food',) :
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5837
#           1       0.87      0.39      0.54       717
#
# avg / total       0.92      0.93      0.91      6554
#  ...................................................
# ('shelter',) :
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5962
#           1       0.87      0.25      0.38       592
#
# avg / total       0.92      0.93      0.91      6554
#  ...................................................
# ('clothing',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6458
#           1       0.75      0.06      0.12        96
#
# avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('money',) :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6393
#           1       1.00      0.03      0.06       161
#
# avg / total       0.98      0.98      0.97      6554
#  ...................................................
# ('missing_people',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6485
#           1       0.00      0.00      0.00        69
#
# avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('refugees',) :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6333
#           1       0.40      0.01      0.02       221
#
# avg / total       0.95      0.97      0.95      6554
#  ...................................................
# ('death',) :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6244
#           1       0.81      0.08      0.15       310
#
# avg / total       0.95      0.96      0.94      6554
#  ...................................................
# ('other_aid',) :
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5681
#           1       0.64      0.02      0.04       873
#
# avg / total       0.84      0.87      0.81      6554
#  ...................................................
# ('infrastructure_related',) :
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6128
#           1       0.20      0.00      0.00       426
#
# avg / total       0.89      0.93      0.90      6554
#  ...................................................
# ('transport',) :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6245
#           1       0.66      0.06      0.11       309
#
# avg / total       0.94      0.95      0.94      6554
#  ...................................................
# ('buildings',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6224
#           1       0.79      0.07      0.13       330
#
# avg / total       0.94      0.95      0.93      6554
#  ...................................................
# ('electricity',) :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6415
#           1       0.73      0.06      0.11       139
#
# avg / total       0.97      0.98      0.97      6554
#  ...................................................
# ('tools',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6506
#           1       0.00      0.00      0.00        48
#
# avg / total       0.99      0.99      0.99      6554
#  ...................................................
# ('hospitals',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       0.00      0.00      0.00        65
#
# avg / total       0.98      0.99      0.99      6554
#  ...................................................
# ('shops',) :
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6525
#           1       0.00      0.00      0.00        29
#
# avg / total       0.99      1.00      0.99      6554
#  ...................................................
# ('aid_centers',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6479
#           1       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('other_infrastructure',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6252
#           1       0.00      0.00      0.00       302
#
# avg / total       0.91      0.95      0.93      6554
#  ...................................................
# ('weather_related',) :
#              precision    recall  f1-score   support
#
#           0       0.87      0.96      0.91      4717
#           1       0.86      0.62      0.72      1837
#
# avg / total       0.86      0.86      0.86      6554
#  ...................................................
# ('floods',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6007
#           1       0.94      0.40      0.56       547
#
# avg / total       0.95      0.95      0.94      6554
#  ...................................................
# ('storm',) :
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      5941
#           1       0.81      0.41      0.54       613
#
# avg / total       0.93      0.94      0.93      6554
#  ...................................................
# ('fire',) :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6475
#           1       0.00      0.00      0.00        79
#
# avg / total       0.98      0.99      0.98      6554
#  ...................................................
# ('earthquake',) :
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      5943
#           1       0.88      0.73      0.80       611
#
# avg / total       0.96      0.97      0.96      6554
#  ...................................................
# ('cold',) :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6415
#           1       0.67      0.04      0.08       139
#
# avg / total       0.97      0.98      0.97      6554
#  ...................................................
# ('other_weather',) :
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6213
#           1       0.57      0.02      0.05       341
#
# avg / total       0.93      0.95      0.93      6554
#  ...................................................
# ('direct_report',) :
#              precision    recall  f1-score   support
#
#           0       0.87      0.99      0.92      5314
#           1       0.87      0.36      0.51      1240
#
# avg / total       0.87      0.87      0.85      6554
#  ...................................................
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
with open('MLclassifier.pkl', 'wb') as file:
    pickle.dump(optimised_model, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8bb2e053f4ce> in <module>()
#       1 import pickle
#       2 with open('MLclassifier.pkl', 'wb') as file:
# ----> 3     pickle.dump(optimised_model, file)
#
# NameError: name 'optimised_model' is not defined

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
